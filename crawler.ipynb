# %%
import os
import threading
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, unquote, urljoin

# Get user input (defaulting to None if not entered)
BASE_URL = input("Enter the URL: ").strip()

start_year_input = input("Enter the start year (leave empty to start from the earliest available): ").strip()
end_year_input = input("Enter the end year (leave empty to download up to the latest available): ").strip()

# Convert inputs to integers if provided, otherwise None
START_YEAR = int(start_year_input) if start_year_input.isdigit() else None
END_YEAR = int(end_year_input) if end_year_input.isdigit() else None

# Set up crawling queue
urls_to_visit = [BASE_URL]
visited_urls = set()
pdf_batch = []
BATCH_SIZE = 35  # Process 35 PDFs at a time


def find_pdf_links(url):
    """Find and return all PDF links on a webpage."""
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        return [urljoin(BASE_URL, link['href']) for link in soup.find_all('a', href=True) if link['href'].endswith('.pdf')]
    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return []


def download_pdfs(pdf_list):
    """Download a batch of PDF files using threads."""
    threads = []
    for pdf_url, paper_year in pdf_list:
        thread = threading.Thread(target=download_pdf, args=(pdf_url, paper_year))
        threads.append(thread)

    for thread in threads:
        thread.start()
    for thread in threads:
        thread.join()


# New Downloader skips downloading if already exist
def download_pdf(pdf_url, paper_year):
    """Download a PDF file and save it under `paper/<year>/` directory if not already downloaded."""
    try:
        # Create directory for the paper year
        save_directory = os.path.join("paper", str(paper_year))
        os.makedirs(save_directory, exist_ok=True)

        # Extract the filename
        pdf_filename = extract_pdf_name(pdf_url)
        pdf_path = os.path.join(save_directory, pdf_filename)

        # **Check if file already exists**
        if os.path.exists(pdf_path):
            print(f"Skipping: {pdf_path} (Already downloaded)")
            return  # **Skip downloading this file**

        # Proceed with download if file doesn't exist
        response = requests.get(pdf_url, headers={'User-Agent': 'Mozilla/5.0'}, stream=True)
        response.raise_for_status()

        with open(pdf_path, "wb") as pdf_file:
            for chunk in response.iter_content(chunk_size=8192):
                pdf_file.write(chunk)

        print(f"Downloaded: {pdf_path}")
    except requests.RequestException as e:
        print(f"Error downloading {pdf_url}: {e}")


# old Downloader redownload if already exist
# def download_pdf(pdf_url, paper_year):
#     """Download a PDF file and save it under `paper/<year>/` directory."""
#     try:
#         response = requests.get(pdf_url, headers={'User-Agent': 'Mozilla/5.0'}, stream=True)
#         response.raise_for_status()
#
#         save_directory = os.path.join("paper", str(paper_year))
#         os.makedirs(save_directory, exist_ok=True)
#
#         pdf_path = os.path.join(save_directory, extract_pdf_name(pdf_url))
#
#         with open(pdf_path, "wb") as pdf_file:
#             for chunk in response.iter_content(chunk_size=8192):
#                 pdf_file.write(chunk)
#
#         print(f"Downloaded: {pdf_path}")
#     except requests.RequestException as e:
#         print(f"Error downloading {pdf_url}: {e}")


def extract_pdf_name(pdf_url):
    """Extracts the filename from a PDF URL."""
    return unquote(urlparse(pdf_url).path.split('/')[-1])


def extract_paper_year(pdf_url):
    """Extracts the year from the URL."""
    parsed_path = urlparse(pdf_url).path.split('/')

    try:
        year_index = parsed_path.index("paper") + 1  # Year comes after 'paper'
        return int(parsed_path[year_index])  # Convert to integer
    except (ValueError, IndexError):
        return None  # Return None if no valid year is found


def crawl_website():
    """Crawl the website for PDF links and download them in batches."""
    global END_YEAR

    while urls_to_visit:
        current_url = urls_to_visit.pop()
        if current_url in visited_urls:
            continue

        visited_urls.add(current_url)
        pdf_links = find_pdf_links(current_url)

        if pdf_links:
            for pdf in pdf_links:
                paper_year = extract_paper_year(pdf)

                if paper_year:
                    if START_YEAR and paper_year < START_YEAR:
                        print(f"Skipping {pdf} (Year {paper_year} is before {START_YEAR})")
                        continue
                    if END_YEAR and paper_year > END_YEAR:
                        print(f"Stopping: Encountered year {paper_year}, which exceeds END_YEAR {END_YEAR}")
                        return  # Stop crawling immediately

                    pdf_batch.append((pdf, paper_year))

                    # Process PDFs in batches of 10
                    if len(pdf_batch) >= BATCH_SIZE:
                        download_pdfs(pdf_batch)
                        pdf_batch.clear()

        # Find new internal links to visit
        try:
            response = requests.get(current_url)
            response.raise_for_status()
            soup = BeautifulSoup(response.content, "html.parser")

            for link in soup.select("li a[href]"):
                new_url = urljoin(BASE_URL, link['href'])
                if new_url.startswith(BASE_URL) and new_url not in visited_urls:
                    urls_to_visit.append(new_url)
        except requests.RequestException:
            continue

    # Download any remaining PDFs in the batch
    if pdf_batch:
        download_pdfs(pdf_batch)
        pdf_batch.clear()


# Run the crawler
crawl_website()
# Out:
# Skipping: paper\1987\fe9fc289c3ff0af142b6d3bead98a923-Paper.pdf (Already downloaded)
# Skipping: paper\1987\fc490ca45c00b1249bbe3554a4fdf6fb-Paper.pdf (Already downloaded)
# Skipping: paper\1987\fbd7939d674997cdb4692d34de8633c4-Paper.pdf (Already downloaded)
# Skipping: paper\1987\f457c545a9ded88f18ecee47145a72c0-Paper.pdf (Already downloaded)
# Skipping: paper\1987\f7177163c833dff4b38fc8d2872f1ec6-Paper.pdf (Already downloaded)
# Skipping: paper\1987\f033ab37c30201f73f142449d037028d-Paper.pdf (Already downloaded)
# Skipping: paper\1987\eccbc87e4b5ce2fe28308fd9f2a7baf3-Paper.pdf (Already downloaded)
# Skipping: paper\1987\ea5d2f1c4608232e07d3aa3d998e5135-Paper.pdf (Already downloaded)
# Skipping: paper\1987\e369853df766fa44e1ed0ff613f563bd-Paper.pdf (Already downloaded)
# Skipping: paper\1987\e4da3b7fbbce2345d7772b0674a318d5-Paper.pdf (Already downloaded)
# Skipping: paper\1987\e2c420d928d4bf8ce0ff2ec19b371514-Paper.pdf (Already downloaded)
# Skipping: paper\1987\d9d4f495e875a2e075a1a4a6e1b9770f-Paper.pdf (Already downloaded)
# Skipping: paper\1987\d82c8d1619ad8176d665453cfb2e55f0-Paper.pdf (Already downloaded)
# Skipping: paper\1987\d67d8ab4f4c10bf22aa353e27879133c-Paper.pdf (Already downloaded)
# Skipping: paper\1987\d645920e395fedad7bbbed0eca3fe2e0-Paper.pdf (Already downloaded)
# Skipping: paper\1987\d3d9446802a44259755d38e6d163e820-Paper.pdf (Already downloaded)
# Skipping: paper\1987\d2ddea18f00665ce8623e36bd4e3c7c5-Paper.pdf (Already downloaded)
# Skipping: paper\1987\d1fe173d08e959397adf34b1d77e88d7-Paper.pdf (Already downloaded)
# Skipping: paper\1987\d09bf41544a3365a46c9077ebb5e35c3-Paper.pdf (Already downloaded)
# Skipping: paper\1987\c9f0f895fb98ab9159f51fd0297e236d-Paper.pdf (Already downloaded)
# Skipping: paper\1987\c81e728d9d4c2f636f067f89cc14862c-Paper.pdf (Already downloaded)
# Skipping: paper\1987\c7e1249ffc03eb9ded908c236bd1996d-Paper.pdf (Already downloaded)
# Skipping: paper\1987\c51ce410c124a10e0db5e4b97fc2af39-Paper.pdf (Already downloaded)
# Skipping: paper\1987\c74d97b01eae257e44aa9d5bade97baf-Paper.pdf (Already downloaded)
# Skipping: paper\1987\c4ca4238a0b923820dcc509a6f75849b-Paper.pdf (Already downloaded)
# Skipping: paper\1987\c20ad4d76fe97759aa27a0c99bff6710-Paper.pdf (Already downloaded)
# Skipping: paper\1987\c16a5320fa475530d9583c34fd356ef5-Paper.pdf (Already downloaded)
# Skipping: paper\1987\c0c7c76d30bd3dcaefc96f40275bdc0a-Paper.pdf (Already downloaded)
# Skipping: paper\1987\b6d767d2f8ed5d21a44b0e5886680cb9-Paper.pdf (Already downloaded)
# Skipping: paper\1987\b53b3a3d6ab90ce0268229151c9bde11-Paper.pdf (Already downloaded)
# Skipping: paper\1987\ad61ab143223efbc24c7d2583be69251-Paper.pdf (Already downloaded)
# Skipping: paper\1987\aab3238922bcc25a6f606eb525ffdc56-Paper.pdf (Already downloaded)
# Skipping: paper\1987\a87ff679a2f3e71d9181a67b7542122c-Paper.pdf (Already downloaded)
# Skipping: paper\1987\a684eceee76fc522773286a895bc8436-Paper.pdf (Already downloaded)
# Skipping: paper\1987\a5bfc9e07964f8dddeb95fc584cd965d-Paper.pdf (Already downloaded)
# Skipping: paper\1987\a5771bce93e200c36f7cd9dfd0e5deaa-Paper.pdf (Already downloaded)Skipping: paper\1987\a3f390d88e4c41f2747bfa2f1b5f87db-Paper.pdf (Already downloaded)
#
# Skipping: paper\1987\9f61408e3afb633e50cdf1b20de6f466-Paper.pdf (Already downloaded)
# Skipping: paper\1987\a1d0c6e83f027327d8461063f4ac58a6-Paper.pdf (Already downloaded)
# Skipping: paper\1987\9bf31c7ff062936a96d3c8bd1f8f2ff3-Paper.pdf (Already downloaded)
# Skipping: paper\1987\9a1158154dfa42caddbd0694a4e9bdc8-Paper.pdf (Already downloaded)
# Skipping: paper\1987\98f13708210194c475687be6106a3b84-Paper.pdf (Already downloaded)
# Skipping: paper\1987\9778d5d219c5080b9a6a17bef029331c-Paper.pdf (Already downloaded)
# Skipping: paper\1987\93db85ed909c13838ff95ccfa94cebd9-Paper.pdf (Already downloaded)
# Skipping: paper\1987\92cc227532d17e56e07902b254dfad10-Paper.pdf (Already downloaded)
# Skipping: paper\1987\8f14e45fceea167a5a36dedd4bea2543-Paper.pdf (Already downloaded)
# Skipping: paper\1987\8613985ec49eb8f757ae6439e879bb2a-Paper.pdf (Already downloaded)
# Skipping: paper\1987\8e296a067a37563370ded05f5a3bf3ec-Paper.pdf (Already downloaded)
# Skipping: paper\1987\7f39f8317fbdb1988ef4c628eba02591-Paper.pdf (Already downloaded)
# Skipping: paper\1987\7cbbc409ec990f19c78c75bd1e06f215-Paper.pdf (Already downloaded)
# Skipping: paper\1987\7647966b7343c29048673252e490f736-Paper.pdf (Already downloaded)
# Skipping: paper\1987\735b90b4568125ed6c3f678819b6e058-Paper.pdf (Already downloaded)
# Skipping: paper\1987\70efdf2ec9b086079795c442636b55fb-Paper.pdf (Already downloaded)
# Skipping: paper\1987\6f4922f45568161a8cdf4ad2299f6d23-Paper.pdf (Already downloaded)
# Skipping: paper\1987\6ea9ab1baa0efb9e19094440c317e21b-Paper.pdf (Already downloaded)
# Skipping: paper\1987\6c8349cc7260ae62e3b1396831a8398f-Paper.pdf (Already downloaded)
# Skipping: paper\1987\67c6a1e7ce56d3d6fa748ab6d9af3fd7-Paper.pdf (Already downloaded)
# Skipping: paper\1987\68d30a9594728bc39aa24be94b319d21-Paper.pdf (Already downloaded)
# Skipping: paper\1987\66f041e16a60928b05a7e228a89c3799-Paper.pdf (Already downloaded)
# Skipping: paper\1987\6512bd43d9caa6e02c990b0a82652dca-Paper.pdf (Already downloaded)
# Skipping: paper\1987\642e92efb79421734881b53e1e1b18b6-Paper.pdf (Already downloaded)
# Skipping: paper\1987\6364d3f0f495b6ab9dcf8d3b5c6e0b01-Paper.pdf (Already downloaded)
# Skipping: paper\1987\54229abfcfa5649e7003b83dd4755294-Paper.pdf (Already downloaded)
# Skipping: paper\1987\45c48cce2e2d7fbdea1afc51c7c6ad26-Paper.pdf (Already downloaded)
# Skipping: paper\1987\4e732ced3463d06de0ca9a15b6153677-Paper.pdf (Already downloaded)
# Skipping: paper\1987\44f683a84163b3523afe57c2e008bc8c-Paper.pdf (Already downloaded)
# Skipping: paper\1987\43ec517d68b6edd3015b3edc9a11367b-Paper.pdf (Already downloaded)
# Skipping: paper\1987\3ef815416f775098fe977004015c6193-Paper.pdf (Already downloaded)
# Skipping: paper\1987\3c59dc048e8850243be8079a5c74d079-Paper.pdf (Already downloaded)
# Skipping: paper\1987\37693cfc748049e45d87b8c7d8b9aacd-Paper.pdf (Already downloaded)
# Skipping: paper\1987\35f4a8d465e6e1edc05f3d8ab658c551-Paper.pdf (Already downloaded)
# Skipping: paper\1987\34173cb38f07f89ddbebc2ac9128303f-Paper.pdf (Already downloaded)
# Skipping: paper\1987\3416a75f4cea9109507cacd8e2f2aefc-Paper.pdf (Already downloaded)
# Skipping: paper\1987\33e75ff09dd601bbe69f351039152189-Paper.pdf (Already downloaded)
# Skipping: paper\1987\32bb90e8976aab5298d5da10fe66f21d-Paper.pdf (Already downloaded)
# Skipping: paper\1987\3295c76acbf4caaed33c36b1b5fc2cb1-Paper.pdf (Already downloaded)
# Skipping: paper\1987\2a38a4a9316c49e5a833517c45d31070-Paper.pdf (Already downloaded)
# Skipping: paper\1987\28dd2c7955ce926456240b2ff0100bde-Paper.pdf (Already downloaded)
# Skipping: paper\1987\2838023a778dfaecdc212708f721b788-Paper.pdf (Already downloaded)
# Skipping: paper\1987\1ff1de774005f8da13f42943881c655f-Paper.pdf (Already downloaded)
# Skipping: paper\1987\1f0e3dad99908345f7439f8ffabdffc4-Paper.pdf (Already downloaded)
# Skipping: paper\1987\1c383cd30b7c298ab50293adfecb7b18-Paper.pdf (Already downloaded)
# Skipping: paper\1987\19ca14e7ea6328a42e0eb13d585e4c22-Paper.pdf (Already downloaded)
# Skipping: paper\1987\182be0c5cdcd5072bb1864cdee4d3d6e-Paper.pdf (Already downloaded)
# Skipping: paper\1987\1679091c5a880faf6fb5e6087eb1b2dc-Paper.pdf (Already downloaded)
# Skipping: paper\1987\14bfa6bb14875e45bba028a21ed38046-Paper.pdf (Already downloaded)
# Skipping: paper\1987\093f65e080a295f8076b1c5722a46aa2-Paper.pdf (Already downloaded)
# Skipping: paper\1987\072b030ba126b2f4b2374f342be9ed44-Paper.pdf (Already downloaded)
# Skipping: paper\1987\03afdbd66e7929b125f8597834fa83a4-Paper.pdf (Already downloaded)
# Skipping: paper\1987\02e74f10e0327ad868d138f2b4fdd6f0-Paper.pdf (Already downloaded)
# Skipping: paper\1988\fc221309746013ac554571fbd180e1c8-Paper.pdf (Already downloaded)
# Skipping: paper\1988\fa7cdfad1a5aaf8370ebeda47a1ff1c3-Paper.pdf (Already downloaded)
# Skipping: paper\1988\f899139df5e1059396431415e770c6dd-Paper.pdf (Already downloaded)
# Skipping: paper\1988\f7e6c85504ce6e82442c770f7c8606f0-Paper.pdf (Already downloaded)
# Skipping: paper\1988\f4b9ec30ad9f68f89b29639786cb62ef-Paper.pdf (Already downloaded)
# Skipping: paper\1988\f2217062e9a397a1dca429e7d70bc6ca-Paper.pdf (Already downloaded)
# Skipping: paper\1988\f0935e4cd5920aa6c7c996a5ee53a70f-Paper.pdf (Already downloaded)
# Skipping: paper\1988\eecca5b6365d9607ee5a9d336962c534-Paper.pdf (Already downloaded)
# Skipping: paper\1988\ec8956637a99787bd197eacd77acce5e-Paper.pdf (Already downloaded)
# Skipping: paper\1988\ec5decca5ed3d6b8079e2e7e7bacc9f2-Paper.pdf (Already downloaded)
# Skipping: paper\1988\ed3d2c21991e3bef5e069713af9fa6ca-Paper.pdf (Already downloaded)
# Skipping: paper\1988\e2ef524fbf3d9fe611d5a8e90fefdc9c-Paper.pdf (Already downloaded)
# Skipping: paper\1988\e00da03b685a0dd18fb6a08af0923de0-Paper.pdf (Already downloaded)
# Skipping: paper\1988\da4fb5c6e93e74d3df8527599fa62642-Paper.pdf (Already downloaded)
# Skipping: paper\1988\d1f491a404d6854880943e5c3cd9ca25-Paper.pdf (Already downloaded)
# Skipping: paper\1988\cedebb6e872f539bef8c3f919874e9d7-Paper.pdf (Already downloaded)
# Skipping: paper\1988\c8ffe9a587b126f152ed3d89a146b445-Paper.pdf (Already downloaded)
# Skipping: paper\1988\c9e1074f5b3f9fc8ea15d152add07294-Paper.pdf (Already downloaded)
# Skipping: paper\1988\c45147dee729311ef5b5c3003946c48f-Paper.pdf (Already downloaded)
# Skipping: paper\1988\bf8229696f7a3bb4700cfddef19fa23f-Paper.pdf (Already downloaded)
# Skipping: paper\1988\bd4c9ab730f5513206b999ec0d90d1fb-Paper.pdf (Already downloaded)
# Skipping: paper\1988\b73ce398c39f506af761d2277d853a92-Paper.pdf (Already downloaded)
# Skipping: paper\1988\b3e3e393c77e35a4a3f3cbd1e429b5dc-Paper.pdf (Already downloaded)
# Skipping: paper\1988\ac627ab1ccbdb62ec96e702f07f6425b-Paper.pdf (Already downloaded)
# Skipping: paper\1988\a97da629b098b75c294dffdc3e463904-Paper.pdf (Already downloaded)
# Skipping: paper\1988\a8f15eda80c50adb0e71943adc8015cf-Paper.pdf (Already downloaded)
# Skipping: paper\1988\a8baa56554f96369ab93e4f3bb068c22-Paper.pdf (Already downloaded)
# Skipping: paper\1988\a5e00132373a7031000fd987a3c9f87b-Paper.pdf (Already downloaded)
# Skipping: paper\1988\a3c65c2974270fd093ee8a9bf8ae7d0b-Paper.pdf (Already downloaded)
# Skipping: paper\1988\a4a042cf4fd6bfb47701cbc8a1653ada-Paper.pdf (Already downloaded)
# Skipping: paper\1988\a0a080f42e6f13b3a2df133f073095dd-Paper.pdf (Already downloaded)
# Skipping: paper\1988\a2557a7b2e94197ff767970b67041697-Paper.pdf (Already downloaded)
# Skipping: paper\1988\9fc3d7152ba9336a670e36d0ed79bc43-Paper.pdf (Already downloaded)
# Skipping: paper\1988\9dcb88e0137649590b755372b040afad-Paper.pdf (Already downloaded)
# Skipping: paper\1988\9b8619251a19057cff70779273e95aa6-Paper.pdf (Already downloaded)
# Skipping: paper\1988\98dce83da57b0395e163467c9dae521b-Paper.pdf (Already downloaded)
# Skipping: paper\1988\9872ed9fc22fc182d371c3e9ed316094-Paper.pdf (Already downloaded)
# Skipping: paper\1988\9766527f2b5d3e95d4a733fcfb77bd7e-Paper.pdf (Already downloaded)
# Skipping: paper\1988\96da2f590cd7246bbde0051047b0d6f7-Paper.pdf (Already downloaded)
# Skipping: paper\1988\903ce9225fca3e988c2af215d4e544d3-Paper.pdf (Already downloaded)
# Skipping: paper\1988\8f85517967795eeef66c225f7883bdcb-Paper.pdf (Already downloaded)
# Skipping: paper\1988\8f53295a73878494e9bc8dd6c3c7104f-Paper.pdf (Already downloaded)
# Skipping: paper\1988\8d5e957f297893487bd98fa830fa6413-Paper.pdf (Already downloaded)
# Skipping: paper\1988\82aa4b0af34c2313a562076992e50aa3-Paper.pdf (Already downloaded)
# Skipping: paper\1988\82161242827b703e6acf9c726942a1e4-Paper.pdf (Already downloaded)
# Skipping: paper\1988\812b4ba287f5ee0bc9d43bbf5bbe87fb-Paper.pdf (Already downloaded)
# Skipping: paper\1988\7f6ffaa6bb0b408017b62254211691b5-Paper.pdf (Already downloaded)
# Skipping: paper\1988\7f1de29e6da19d22b51c68001e7e0e54-Paper.pdf (Already downloaded)
# Skipping: paper\1988\7ef605fc8dba5425d6965fbd4c8fbe1f-Paper.pdf (Already downloaded)
# Skipping: paper\1988\7e7757b1e12abcb736ab9a754ffb617a-Paper.pdf (Already downloaded)
# Skipping: paper\1988\76dc611d6ebaafc66cc0879c71b5db5c-Paper.pdf (Already downloaded)
# Skipping: paper\1988\73278a4a86960eeb576a8fd4c9ec6997-Paper.pdf (Already downloaded)
# Skipping: paper\1988\6cdd60ea0045eb7a6ec44c54d29ed402-Paper.pdf (Already downloaded)
# Skipping: paper\1988\6c4b761a28b734fe93831e3fb400ce87-Paper.pdf (Already downloaded)
# Skipping: paper\1988\698d51a19d8a121ce581499d7b701668-Paper.pdf (Already downloaded)
# Skipping: paper\1988\6974ce5ac660610b44d9b9fed0ff9548-Paper.pdf (Already downloaded)
# Skipping: paper\1988\65ded5353c5ee48d0b7d48c591b8f430-Paper.pdf (Already downloaded)
# Skipping: paper\1988\65b9eea6e1cc6bb9f0cd2a47751a186f-Paper.pdf (Already downloaded)
# Skipping: paper\1988\5fd0b37cd7dbbb00f97ba6ce92bf5add-Paper.pdf (Already downloaded)
# Skipping: paper\1988\5f93f983524def3dca464469d2cf9f3e-Paper.pdf (Already downloaded)
# Skipping: paper\1988\5ef059938ba799aaa845e1c2e8a762bd-Paper.pdf (Already downloaded)
# Skipping: paper\1988\4c5bde74a8f110656874902f07378009-Paper.pdf (Already downloaded)
# Skipping: paper\1988\5878a7ab84fb43402106c575658472fa-Paper.pdf (Already downloaded)
# Skipping: paper\1988\4c56ff4ce4aaf9573aa5dff913df997a-Paper.pdf (Already downloaded)
# Skipping: paper\1988\47d1e990583c9c67424d369f3414728e-Paper.pdf (Already downloaded)
# Skipping: paper\1988\3def184ad8f4755ff269862ea77393dd-Paper.pdf (Already downloaded)
# Skipping: paper\1988\42a0e188f5033bc65bf8d78622277c4e-Paper.pdf (Already downloaded)
# Skipping: paper\1988\3988c7f88ebcb58c6ce932b957b6f332-Paper.pdf (Already downloaded)
# Skipping: paper\1988\38b3eff8baf56627478ec76a704e9b52-Paper.pdf (Already downloaded)
# Skipping: paper\1988\37a749d808e46495a8da1e5352d03cae-Paper.pdf (Already downloaded)
# Skipping: paper\1988\3636638817772e42b59d74cff571fbb3-Paper.pdf (Already downloaded)
# Skipping: paper\1988\31fefc0e570cb3860f2a6d4b38c6490d-Paper.pdf (Already downloaded)
# Skipping: paper\1988\2b44928ae11fb9384c4cf38708677c48-Paper.pdf (Already downloaded)
# Skipping: paper\1988\2b24d495052a8ce66358eb576b8912c8-Paper.pdf (Already downloaded)
# Skipping: paper\1988\2a79ea27c279e471f4d180b08d62b00a-Paper.pdf (Already downloaded)
# Skipping: paper\1988\2723d092b63885e0d7c260cc007e8b9d-Paper.pdf (Already downloaded)
# Skipping: paper\1988\202cb962ac59075b964b07152d234b70-Paper.pdf (Already downloaded)
# Skipping: paper\1988\1ff8a7b5dc7a7d1f0ed65aaa29c04b1e-Paper.pdf (Already downloaded)
# Skipping: paper\1988\1d7f7abc18fcb43975065399b0d1e48e-Paper.pdf (Already downloaded)
# Skipping: paper\1988\1c9ac0159c94d8d0cbedc973445af2da-Paper.pdf (Already downloaded)
# Skipping: paper\1988\1afa34a7f984eeabdbb0a7d494132ee5-Paper.pdf (Already downloaded)
# Skipping: paper\1988\149e9677a5989fd342ae44213df68868-Paper.pdf (Already downloaded)
# Skipping: paper\1988\140f6969d5213fd0ece03148e62e461e-Paper.pdf (Already downloaded)
# Skipping: paper\1988\1385974ed5904a438616ff7bdb3f7439-Paper.pdf (Already downloaded)
# Skipping: paper\1988\0f28b5d49b3020afeecd95b4009adf4c-Paper.pdf (Already downloaded)
# Stopping: Encountered year 1989, which exceeds END_YEAR 1988
